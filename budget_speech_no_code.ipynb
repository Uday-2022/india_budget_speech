# %% [markdown]
# # Government Budget Speech - 25-26 (Key numerical pointers)

# %% [markdown]
# ![Government Budget Analysis](openai_image_1.jpg)

# %% [markdown]
# ## Key Values highlighted in budget speech

# %%
# Out:
#                                               Category  \
# 0                  (This programme, 1.7 crore farmers)
# 1    (Farmers, the need, the cultivated area, 50 pe...
# 2    (Kisan Credit Cards (KCC) facilitate short ter...
# 3    (The loan limit, the Modified Interest Subvent...
# 4    (The loan limit, the Modified Interest Subvent...
# ..                                                 ...
# 116  (A person, income, ` 18 lakh, a benefit, tax, ...
# 117  (A person, an income, 25 lakh, a benefit, 25%,...
# 118  (A person, an income, 25 lakh, a benefit, 25%,...
# 119  (a result, these proposals, revenue, about ₹ 1...
# 120  (a result, these proposals, revenue, about ₹ 1...
#
#                         Value
# 0         ( 1.7 crore, crore)
# 1    ( 50 per cent, per cent)
# 2         ( 7.7 crore, crore)
# 3             ( 3 lakh, lakh)
# 4             ( 5 lakh, lakh)
# ..                        ...
# 116                  (30%, %)
# 117          ( 25 lakh, lakh)
# ...

# %% [markdown]
# ## Word Cloud of topics highlighted in sentences with values

# %% [markdown]
# **Note: I have classified data into value and percentage terms (values in crores and %)**

# %% [markdown]
# ## Scatter plot to show Numerical values in crore

# %% [markdown]
# ## Bar Chart to show Percentage values

# %%
# Out:
# C:\Users\91981\AppData\Local\Temp\ipykernel_5672\3814697344.py:8: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#
# C:\Users\91981\AppData\Local\Temp\ipykernel_5672\3814697344.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ## Above plot in interactive mode
